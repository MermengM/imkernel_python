# %%
from OCC.Core.BRepPrimAPI import BRepPrimAPI_MakeBox
from OCC.Core.gp import gp_Pnt
import imkernel

# %%
box = BRepPrimAPI_MakeBox(gp_Pnt(0, 0, 0), 100, 60, 40).Shape()
#显示shape
imkernel.v3d.show_occ_shape(box)
# Out:
# 2024-09-24 13:01:08.368 | SUCCESS  | imkernel.v3d.occ_utils:shape_to_obj:65 - 导出成功：C:\Users\24446\AppData\Local\Temp\imkernel\occ_temp\shape_to_obj_temp.obj
# C:\Users\24446\anaconda3\envs\imkernel_python311\Lib\site-packages\pyvista\jupyter\notebook.py:37: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (C:\Users\24446\anaconda3\envs\imkernel_python311\Lib\site-packages\trame\widgets\__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
