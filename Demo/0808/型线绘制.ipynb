# %%
from Demo.Algo.cimsh.main import make_molded
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.font_manager as fm

result = make_molded(Z_height=100)

# 提取 x, y, z 坐标
x = [point['x'] for point in result]
y = [point['y'] for point in result]
z = [point['z'] for point in result]

# 设置中文字体，请确保您的系统中安装了这个字体
# 如果没有 SimHei，可以尝试其他中文字体，如 Microsoft YaHei
font_path = fm.findfont(fm.FontProperties(family='SimHei'))
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
# 创建 3D 图形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 绘制 3D 散点图
scatter = ax.scatter(x, y, z, c=z, cmap='viridis')

# 添加颜色条
plt.colorbar(scatter)

# 设置坐标轴标签
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# 设置标题
plt.title('型线')

# 显示图形
plt.show()
# Out:
# Chord_Length: :  50.0
# Upper_Max_Width: :  0.4149
# Upper_Max_Width_Loc: :  0.2098
# Upper_Angle: :  0.0582
# Upper_tip_coeff: :  0.4492
# Upper_aft_part_shape: :  0.3339
# Lower_max_width: :  0.234
# Lower_max_width_loc: :  0.7289
# Lower_Angle: :  0.2497
# Lower_tip_coeff: :  0.52
# Lower_aft_part_shape: :  0.8523
# Tangent_Leading_Edge: :  0.5
# Z_height: :  100.0
# [42, 111, 68, 79]
# 38.965875095949905
# 23.351512416334884
