# %%
import pandas as pd
from imkernel.model import System

# %% [markdown]
# # 创建单元参数Dataframe

# %%
parameter_df = pd.DataFrame(data=[
    ('DesginParameters', 'ElevenParameters', 'Chord_Length'),
    ('DesginParameters', 'ElevenParameters', 'Upper_Max_Width'),
    ('DesginParameters', 'ElevenParameters', 'Upper_Max_Width_Loc'),
    ('DesginParameters', 'ElevenParameters', 'Upper_Angle'),
    ('DesginParameters', 'ElevenParameters', 'Upper_tip_coeff'),
    ('DesginParameters', 'ElevenParameters', 'Upper_aft_part_shape'),
    ('DesginParameters', 'ElevenParameters', 'Lower_max_width'),
    ('DesginParameters', 'ElevenParameters', 'Lower_max_width_loc'),
    ('DesginParameters', 'ElevenParameters', 'Lower_Angle'),
    ('DesginParameters', 'ElevenParameters', 'Lower_tip_coeff'),
    ('DesginParameters', 'ElevenParameters', 'Lower_aft_part_shape'),
    ('DesginParameters', 'ElevenParameters', 'Tangent_Leading_Edge'),
    ('SectionPoints', 'x'),
    ('SectionPoints', 'y'),
    ('SectionPoints', 'z'),
    ('CurvePonits', 'x'),
    ('CurvePonits', 'y'),
    ('CurvePonits', 'z'),
    ('FinishingPoint', 'x'),
    ('FinishingPoint', 'y'),
    ('FinishingPoint', 'z'),
    ('FinishingPoint', 'i'),
    ('FinishingPoint', 'j'),
    ('FinishingPoint', 'k'),
    ('BasicParameters', 'A'),
    ('BasicParameters', 'B'),
    ('BasicParameters', 'C'),
])

# %% [markdown]
# # 单元对象修改

# %%
system = System()
system.build_from_dataframes(parameter_df)
system.add_object_to_node("ElevenParameters", "新增参数")
parameter_df_new = system.get_element_df()
parameter_df_new
# Out:
# 2024-08-02 09:24:10.193 | INFO     | imkernel.model.new_model:add_object_to_node:132 - 增加 '新增参数' (ID: 68) 到 'ElevenParameters'.
#                    0                 1                     2
# 0   DesginParameters  ElevenParameters          Chord_Length
# 1   DesginParameters  ElevenParameters       Upper_Max_Width
# 2   DesginParameters  ElevenParameters   Upper_Max_Width_Loc
# 3   DesginParameters  ElevenParameters           Upper_Angle
# 4   DesginParameters  ElevenParameters       Upper_tip_coeff
# 5   DesginParameters  ElevenParameters  Upper_aft_part_shape
# 6   DesginParameters  ElevenParameters       Lower_max_width
# 7   DesginParameters  ElevenParameters   Lower_max_width_loc
# 8   DesginParameters  ElevenParameters           Lower_Angle
# 9   DesginParameters  ElevenParameters        Lower_tip_coef
# 10  DesginParameters  ElevenParameters  Lower_aft_part_shape
# 11  DesginParameters  ElevenParameters  Tangent_Leading_Edge
# 12  DesginParameters  ElevenParameters                  新增参数
# 13     SectionPoints                 x                  None
# 14     SectionPoints                 y                  None
# 15     SectionPoints                 z                  None
# 16       CurvePonits                 x                  None
# 17       CurvePonits                 y                  None
# 18       CurvePonits                 z                  None
# 19    FinishingPoint                 x                  None
# 20    FinishingPoint                 y                  None
# 21    FinishingPoint                 z                  None
# 22    FinishingPoint                 i                  None
# 23    FinishingPoint                 j                  None
# 24    FinishingPoint                 k                  None
# 25   BasicParameters                 A                  None
# 26   BasicParameters                 B                  None
# 27   BasicParameters                 C                  None
