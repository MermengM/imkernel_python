# %%
import pandas as pd
from imkernel.model import System
from algo import make_molded

# %% [markdown]
# # 创建单元对象dataframe

# %%
object_df = pd.DataFrame(data=[
    ('Blade', 'BladeCross', 'BladePolyLine', 'ElevenParameters'),
    ('Blade', 'BladeCross', 'BladePolyLine', 'SectionPoints'),
    ('Blade', 'BladeCross', 'BladePolyLine', 'CurvePonits'),
    ('Blade', 'BladeCross', 'BladePolyLine', 'cpts'),
    ('Blade', 'FinishingPoint'),
    ('Blade', 'ClosedBladeCross'),
    ('machine', 'BasicParameters'),
    ('machine', 'MachiningParameter'),
    ('cutter', 'BasicParameters'),
    ('cutter', 'P_Parameter')
])
parameter_df = pd.DataFrame(data=[
    ('DesginParameters', 'ElevenParameters', 'Chord_Length'),
    ('DesginParameters', 'ElevenParameters', 'Upper_Max_Width'),
    ('DesginParameters', 'ElevenParameters', 'Upper_Max_Width_Loc'),
    ('DesginParameters', 'ElevenParameters', 'Upper_Angle'),
    ('DesginParameters', 'ElevenParameters', 'Upper_tip_coeff'),
    ('DesginParameters', 'ElevenParameters', 'Upper_aft_part_shape'),
    ('DesginParameters', 'ElevenParameters', 'Lower_max_width'),
    ('DesginParameters', 'ElevenParameters', 'Lower_max_width_loc'),
    ('DesginParameters', 'ElevenParameters', 'Lower_Angle'),
    ('DesginParameters', 'ElevenParameters', 'Lower_tip_coeff'),
    ('DesginParameters', 'ElevenParameters', 'Lower_aft_part_shape'),
    ('DesginParameters', 'ElevenParameters', 'Tangent_Leading_Edge'),
    ('SectionPoints', 'x'),
    ('SectionPoints', 'y'),
    ('SectionPoints', 'z'),
    ('CurvePonits', 'x'),
    ('CurvePonits', 'y'),
    ('CurvePonits', 'z'),
    ('FinishingPoint', 'x'),
    ('FinishingPoint', 'y'),
    ('FinishingPoint', 'z'),
    ('FinishingPoint', 'i'),
    ('FinishingPoint', 'j'),
    ('FinishingPoint', 'k'),
    ('BasicParameters', 'A'),
    ('BasicParameters', 'B'),
    ('BasicParameters', 'C'),
])

# %% [markdown]
# # 单元模型创建

# %%
# 单元模型创建
system = System()
system.build_from_dataframes(object_df, parameter_df)
elements_df = system.get_element_df()
elements_df
# Out:
# 2024-08-02 13:53:47.613 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Chord_Length'
# 2024-08-02 13:53:47.614 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Upper_Max_Width'
# 2024-08-02 13:53:47.614 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Upper_Max_Width_Loc'
# 2024-08-02 13:53:47.615 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Upper_Angle'
# 2024-08-02 13:53:47.616 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Upper_tip_coeff'
# 2024-08-02 13:53:47.617 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Upper_aft_part_shape'
# 2024-08-02 13:53:47.618 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Lower_max_width'
# 2024-08-02 13:53:47.618 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Lower_max_width_loc'
# 2024-08-02 13:53:47.619 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Lower_Angle'
# 2024-08-02 13:53:47.619 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Lower_tip_coeff'
# 2024-08-02 13:53:47.620 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Lower_aft_part_shape'
# 2024-08-02 13:53:47.620 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'ElevenParameters' 匹配到参数： 'Tangent_Leading_Edge'
# 2024-08-02 13:53:47.620 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'SectionPoints' 匹配到参数： 'x'
# 2024-08-02 13:53:47.621 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'SectionPoints' 匹配到参数： 'y'
# 2024-08-02 13:53:47.621 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'SectionPoints' 匹配到参数： 'z'
# 2024-08-02 13:53:47.621 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'CurvePonits' 匹配到参数： 'x'
# 2024-08-02 13:53:47.622 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'CurvePonits' 匹配到参数： 'y'
# 2024-08-02 13:53:47.623 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'CurvePonits' 匹配到参数： 'z'
# 2024-08-02 13:53:47.624 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'FinishingPoint' 匹配到参数： 'x'
# 2024-08-02 13:53:47.625 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'FinishingPoint' 匹配到参数： 'y'
# 2024-08-02 13:53:47.626 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'FinishingPoint' 匹配到参数： 'z'
# 2024-08-02 13:53:47.626 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'FinishingPoint' 匹配到参数： 'i'
# 2024-08-02 13:53:47.627 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'FinishingPoint' 匹配到参数： 'j'
# 2024-08-02 13:53:47.628 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'FinishingPoint' 匹配到参数： 'k'
# 2024-08-02 13:53:47.628 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'BasicParameters' 匹配到参数： 'A'
# 2024-08-02 13:53:47.628 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'BasicParameters' 匹配到参数： 'A'
# 2024-08-02 13:53:47.629 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'BasicParameters' 匹配到参数： 'B'
# 2024-08-02 13:53:47.629 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'BasicParameters' 匹配到参数： 'B'
# 2024-08-02 13:53:47.630 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'BasicParameters' 匹配到参数： 'C'
# 2024-08-02 13:53:47.630 | INFO     | imkernel.model.new_model:_add_parameter_from_row:456 - 对象：'BasicParameters' 匹配到参数： 'C'
#           0                   1              2                 3  \
# 0     Blade          BladeCross  BladePolyLine  ElevenParameters
# 1     Blade          BladeCross  BladePolyLine  ElevenParameters
# 2     Blade          BladeCross  BladePolyLine  ElevenParameters
# 3     Blade          BladeCross  BladePolyLine  ElevenParameters
# 4     Blade          BladeCross  BladePolyLine  ElevenParameters
# 5     Blade          BladeCross  BladePolyLine  ElevenParameters
# 6     Blade          BladeCross  BladePolyLine  ElevenParameters
# 7     Blade          BladeCross  BladePolyLine  ElevenParameters
# 8     Blade          BladeCross  BladePolyLine  ElevenParameters
# 9     Blade          BladeCross  BladePolyLine  ElevenParameters
# 10    Blade          BladeCross  BladePolyLine  ElevenParameters
# 11    Blade          BladeCross  BladePolyLine  ElevenParameters
# 12    Blade          BladeCross  BladePolyLine     SectionPoints
# 13    Blade          BladeCross  BladePolyLine     SectionPoints
# 14    Blade          BladeCross  BladePolyLine     SectionPoints
# 15    Blade          BladeCross  BladePolyLine       CurvePonits
# 16    Blade          BladeCross  BladePolyLine       CurvePonits
# 17    Blade          BladeCross  BladePolyLine       CurvePonits
# 18    Blade          BladeCross  BladePolyLine              cpts
# 19    Blade      FinishingPoint              x              None
# 20    Blade      FinishingPoint              y              None
# 21    Blade      FinishingPoint              z              None
# 22    Blade      FinishingPoint              i              None
# 23    Blade      FinishingPoint              j              None
# 24    Blade      FinishingPoint              k              None
# 25    Blade    ClosedBladeCross           None              None
# 26  machine     BasicParameters              A              None
# 27  machine     BasicParameters              B              None
# 28  machine     BasicParameters              C              None
# 29  machine  MachiningParameter           None              None
# 30   cutter     BasicParameters              A              None
# 31   cutter     BasicParameters              B              None
# 32   cutter     BasicParameters              C              None
# 33   cutter         P_Parameter           None              None
#
#                        4
# 0           Chord_Length
# 1        Upper_Max_Width
# 2    Upper_Max_Width_Loc
# 3            Upper_Angle
# 4        Upper_tip_coeff
# 5   Upper_aft_part_shape
# 6        Lower_max_width
# 7    Lower_max_width_loc
# 8            Lower_Angle
# 9        Lower_tip_coeff
# 10  Lower_aft_part_shape
# 11  Tangent_Leading_Edge
# 12                     x
# 13                     y
# 14                     z
# 15                     x
# 16                     y
# 17                     z
# 18                  None
# 19                  None
# 20                  None
# 21                  None
# 22                  None
# 23                  None
# 24                  None
# 25                  None
# 26                  None
# 27                  None
# 28                  None
# 29                  None
# 30                  None
# 31                  None
# 32                  None
# 33                  None

# %% [markdown]
# # 添加一套数据

# %%
system.set_node_data("ElevenParameters", "Chord_Length", 0.5)
system.set_node_data("ElevenParameters", "Upper_Max_Width", 0.5)
system.set_node_data("ElevenParameters", "Upper_Max_Width_Loc", 0.5)
system.set_node_data("ElevenParameters", "Upper_Angle", 0.5)
system.set_node_data("ElevenParameters", "Upper_tip_coeff", 0.5)
system.set_node_data("ElevenParameters", "Upper_aft_part_shape", 0.5)
system.set_node_data("ElevenParameters", "Lower_max_width", 0.5)
system.set_node_data("ElevenParameters", "Lower_max_width_loc", 0.5)
system.set_node_data("ElevenParameters", "Lower_Angle", 0.5)
system.set_node_data("ElevenParameters", "Lower_tip_coeff", 0.5)
system.set_node_data("ElevenParameters", "Lower_aft_part_shape", 0.5)
system.set_node_data("ElevenParameters", "Tangent_Leading_Edge", 0.5)

# %% [markdown]
# # 输出十一参数数据

# %%
ElevenParameters_df = system.get_parameters_df_for_object('ElevenParameters')
ElevenParameters_df1 = system.get_parameters_for_object('ElevenParameters')
tttt = system.get_parameters_by_node_name('ElevenParameters')
elevenParameters_input_dict = system.get_parameters_dict_by_node_name('ElevenParameters')

# %% [markdown]
# # 算法

# %%
result = make_molded(**elevenParameters_input_dict)
system.add_node_data("SectionPoints", result)
x = system.get_parameters_dict_by_node_name("SectionPoints")
result_df = system.get_parameters_df_for_object('SectionPoints')
result_df
# Out:
# Chord_Length: :  0.5
# Upper_Max_Width: :  0.5
# Upper_Max_Width_Loc: :  0.5
# Upper_Angle: :  0.5
# Upper_tip_coeff: :  0.5
# Upper_aft_part_shape: :  0.5
# Lower_max_width: :  0.5
# Lower_max_width_loc: :  0.5
# Lower_Angle: :  0.5
# Lower_tip_coeff: :  0.5
# Lower_aft_part_shape: :  0.5
# Tangent_Leading_Edge: :  0.5
# Z_height: :  10.0
# [42, 111, 68, 79]
# 0.31080739630925
# 0.3059479862707246
#   Parameter                                              Value
# 0         x  [0.001, 0.0011683086432292046, 0.0016683013885...
# 1         y  [0.001, 0.0029351213708448806, 0.0048593618055...
# 2         z  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....
