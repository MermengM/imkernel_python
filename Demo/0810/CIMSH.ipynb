# %%
from imkernel.model.new_model import BaseNode, Element, UnitObject, UnitParameter, UnitData
import pandas as pd

# %% [markdown]
# # 统一模型

# %% [markdown]
# ## 单元模型 - 创建

# %%
Blade = pd.DataFrame(data=[
    ('Blade', 'BladeCross', 'BladePolyLine'),
])
Machine = pd.DataFrame(data=[
    ('machine', 'BasicParameters'),
    ('machine', 'MachiningParameter'),
])
Cutter = pd.DataFrame(data=[
    ('cutter', 'BasicParameters'),
    ('cutter', 'PerformanceParameter'),
])

# %%
CIMSH_Element = Element()
CIMSH_Element.add_object_from_dataframe([Blade, Machine, Cutter])
CIMSH_Element.to_df()
# Out:
#          0                     1              2
# 0    Blade            BladeCross  BladePolyLine
# 1  machine       BasicParameters           None
# 2  machine    MachiningParameter           None
# 3   cutter       BasicParameters           None
# 4   cutter  PerformanceParameter           None

# %% [markdown]
# ## 新增单元对象到指定节点

# %%
# 单层添加
CIMSH_Element.add_object_to_node("BladeCross", "BladePolyLineTest")
# 多层添加
CIMSH_Element.add_nested_objects("BladePolyLineTest", ['A', 'B', 'C'])
CIMSH_Element.to_df()
# Out:
# 2024-08-09 16:28:44.142 | INFO     | imkernel.model.new_model:add_object_to_node:126 - 增加 'BladePolyLineTest' (ID: 13) 到 'BladeCross'.
# 2024-08-09 16:28:44.144 | INFO     | imkernel.model.new_model:add_nested_objects:159 - 增加 'A' (ID: 14) 到 'BladePolyLineTest'.
# 2024-08-09 16:28:44.145 | INFO     | imkernel.model.new_model:add_nested_objects:159 - 增加 'B' (ID: 15) 到 'A'.
# 2024-08-09 16:28:44.145 | INFO     | imkernel.model.new_model:add_nested_objects:159 - 增加 'C' (ID: 16) 到 'B'.
#          0                     1                  2     3     4     5
# 0    Blade            BladeCross      BladePolyLine  None  None  None
# 1    Blade            BladeCross  BladePolyLineTest     A     B     C
# 2  machine       BasicParameters               None  None  None  None
# 3  machine    MachiningParameter               None  None  None  None
# 4   cutter       BasicParameters               None  None  None  None
# 5   cutter  PerformanceParameter               None  None  None  None

# %% [markdown]
# ## 移除指定单元对象

# %%
CIMSH_Element.remove_node("BladePolyLineTest")
CIMSH_Element.to_df()
# Out:
# 2024-08-09 16:28:44.482 | INFO     | imkernel.model.new_model:remove_node:184 - 已删除节点 'BladePolyLineTest' 及其所有子节点.
#          0                     1              2
# 0    Blade            BladeCross  BladePolyLine
# 1  machine       BasicParameters           None
# 2  machine    MachiningParameter           None
# 3   cutter       BasicParameters           None
# 4   cutter  PerformanceParameter           None

# %% [markdown]
# ## 根据单元对象名查找

# %%
x  # 机器
machine_node_df = CIMSH_Element.find_node_to_df("machine")
machine_node_df
# Out:
#          0                   1
# 0  machine     BasicParameters
# 1  machine  MachiningParameter

# %%
# 根节点
Element_node_df = CIMSH_Element.find_node_to_df("Element")
Element_node_df
# Out:
#          0        1                     2              3
# 0  Element    Blade            BladeCross  BladePolyLine
# 1  Element  machine       BasicParameters           None
# 2  Element  machine    MachiningParameter           None
# 3  Element   cutter       BasicParameters           None
# 4  Element   cutter  PerformanceParameter           None

# %% [markdown]
# ## 单元参数 - 创建

# %%
Parameter_df = pd.DataFrame(data=[
    ('BladeDesginParameters', 'ElevenParameters', 'Chord_Length'),
    ('BladeDesginParameters', 'ElevenParameters', 'Upper_Max_Width'),
    ('BladeDesginParameters', 'ElevenParameters', 'Upper_Max_Width_Loc'),
    ('BladeDesginParameters', 'ElevenParameters', 'Upper_Angle'),
    ('BladeDesginParameters', 'ElevenParameters', 'Upper_tip_coeff'),
    ('BladeDesginParameters', 'ElevenParameters', 'Upper_aft_part_shape'),
    ('BladeDesginParameters', 'ElevenParameters', 'Lower_max_width'),
    ('BladeDesginParameters', 'ElevenParameters', 'Lower_max_width_loc'),
    ('BladeDesginParameters', 'ElevenParameters', 'Lower_Angle'),
    ('BladeDesginParameters', 'ElevenParameters', 'Lower_tip_coeff'),
    ('BladeDesginParameters', 'ElevenParameters', 'Lower_aft_part_shape'),
    ('BladeDesginParameters', 'ElevenParameters', 'Tangent_Leading_Edge'),
    ('BladeDesginParameters', 'cpts', 'x'),
    ('BladeDesginParameters', 'cpts', 'y'),
    ('BladeDesginParameters', 'cpts', 'z'),
    ('BladeDesginParameters', 'CurvePonits', 'x'),
    ('BladeDesginParameters', 'CurvePonits', 'y'),
    ('BladeDesginParameters', 'CurvePonits', 'z'),
    ('BladeDesginParameters', 'SectionPoints', 'x'),
    ('BladeDesginParameters', 'SectionPoints', 'y'),
    ('BladeDesginParameters', 'SectionPoints', 'z'),
    ('FinishingPoint', 'x'),
    ('FinishingPoint', 'y'),
    ('FinishingPoint', 'z'),
    ('FinishingPoint', 'i'),
    ('FinishingPoint', 'j'),
    ('FinishingPoint', 'k'),
    ('BladeMachiningParameters', 'machine', 'BasicParameters', 'Type'),
    ('MachiningParameters', 'machine', 'MachiningParameters', 'Speed'),
    ('MachiningParameters', 'cutter', 'MachiningParameters', 'Speed'),
    ('BasicParameters', 'B'),
    ('BasicParameters', 'C'),
])

# 单元参数
CIMSH_Element_Parameter = Element()
CIMSH_Element_Parameter.add_object_from_dataframe(Parameter_df)
CIMSH_Element_Parameter.to_df()
# Out:
#                            0                 1                     2      3
# 0      BladeDesginParameters  ElevenParameters          Chord_Length   None
# 1      BladeDesginParameters  ElevenParameters       Upper_Max_Width   None
# 2      BladeDesginParameters  ElevenParameters   Upper_Max_Width_Loc   None
# 3      BladeDesginParameters  ElevenParameters           Upper_Angle   None
# 4      BladeDesginParameters  ElevenParameters       Upper_tip_coeff   None
# 5      BladeDesginParameters  ElevenParameters  Upper_aft_part_shape   None
# 6      BladeDesginParameters  ElevenParameters       Lower_max_width   None
# 7      BladeDesginParameters  ElevenParameters   Lower_max_width_loc   None
# 8      BladeDesginParameters  ElevenParameters           Lower_Angle   None
# 9      BladeDesginParameters  ElevenParameters       Lower_tip_coeff   None
# 10     BladeDesginParameters  ElevenParameters  Lower_aft_part_shape   None
# ...

# %%
## 单元参数查找

# %%
ElevenParameters_df = CIMSH_Element_Parameter.find_node_to_df("ElevenParameters")
ElevenParameters_df
# Out:
#                    0                     1
# 0   ElevenParameters          Chord_Length
# 1   ElevenParameters       Upper_Max_Width
# 2   ElevenParameters   Upper_Max_Width_Loc
# 3   ElevenParameters           Upper_Angle
# 4   ElevenParameters       Upper_tip_coeff
# 5   ElevenParameters  Upper_aft_part_shape
# 6   ElevenParameters       Lower_max_width
# 7   ElevenParameters   Lower_max_width_loc
# 8   ElevenParameters           Lower_Angle
# 9   ElevenParameters       Lower_tip_coeff
# 10  ElevenParameters  Lower_aft_part_shape
# 11  ElevenParameters  Tangent_Leading_Edge

# %%
## 单元参数关联到单元对象

# %%
# 单个参数关联
CIMSH_Element.bind_parameter_to_object(parameter_info="Chord_Length", object_path=['Blade', 'BladeCross', 'BladePolyLine'])

# 使用参数列表关联
eleven_parameters = [
    "Upper_Max_Width",
    "Upper_Max_Width_Loc",
    "Upper_Angle",
    "Upper_tip_coeff",
    "Upper_aft_part_shape",
    "Lower_max_width",
    "Lower_max_width_loc",
    "Lower_Angle",
    "Lower_tip_coeff",
    "Lower_aft_part_shape",
    "Tangent_Leading_Edge"
]
CIMSH_Element.bind_parameter_to_object(
    parameter_info=eleven_parameters,
    object_path=['Blade', 'BladeCross', 'BladePolyLine']
)
# 添加 x y z
CIMSH_Element.bind_parameter_to_object(
    parameter_info=['x', 'y', 'z'],
    object_path=['Blade', 'BladeCross', 'BladePolyLine']
)
CIMSH_Element.to_df()
# Out:
# 2024-08-09 16:28:46.129 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Chord_Length' 关联到对象 'BladePolyLine'
# 2024-08-09 16:28:46.130 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Upper_Max_Width' 关联到对象 'BladePolyLine'
# 2024-08-09 16:28:46.130 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Upper_Max_Width_Loc' 关联到对象 'BladePolyLine'
# 2024-08-09 16:28:46.131 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Upper_Angle' 关联到对象 'BladePolyLine'
# 2024-08-09 16:28:46.133 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Upper_tip_coeff' 关联到对象 'BladePolyLine'
# 2024-08-09 16:28:46.134 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Upper_aft_part_shape' 关联到对象 'BladePolyLine'
# 2024-08-09 16:28:46.134 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 'Lower_max_width' 关联到对象 'BladePolyLine'
# ...

# %% [markdown]
# ## 方法模型 - 创建

# %%
method_df = pd.DataFrame(data=[
    ('叶片设计方法', '型线生成方法(Python型线程序)', '十一参数法'),
    ('叶片设计方法', '型线生成方法(Python型线程序)', '采样点法'),
    ('叶片设计方法', '曲面生成法(PeriodicTsplineSkinningLib.dll)'),
    ('叶片设计方法', '端面封闭生成法(Fill_empty_obj2stl.py)'),
    ('轨迹规划方法', '精加工算法'),
    ('加工规划方法', 'NC代码生成方法(FiveAxisSolver.dll)'),
    ('检测方法', '采样算法'),
    ('检测方法', '配准算法'),
    ('人工智能优化方法', '复杂型面加工特征参数优化迭代算法'),
    ('人工智能优化方法', '面向复杂型面的铣削参数优化方法')
])
# 方法模型
CIMSH_Method = Element()
CIMSH_Method.add_object_from_dataframe(method_df)
CIMSH_Method.to_df()
# Out:
#           0                                      1      2
# 0    叶片设计方法                     型线生成方法(Python型线程序)  十一参数法
# 1    叶片设计方法                     型线生成方法(Python型线程序)   采样点法
# 2    叶片设计方法  曲面生成法(PeriodicTsplineSkinningLib.dll)   None
# 3    叶片设计方法         端面封闭生成法(Fill_empty_obj2stl.py)   None
# 4    轨迹规划方法                                  精加工算法   None
# 5    加工规划方法           NC代码生成方法(FiveAxisSolver.dll)   None
# 6      检测方法                                   采样算法   None
# 7      检测方法                                   配准算法   None
# 8  人工智能优化方法                       复杂型面加工特征参数优化迭代算法   None
# 9  人工智能优化方法                        面向复杂型面的铣削参数优化方法   None

# %% [markdown]
# ## 方法参数 - 创建

# %%
CIMSH_Parameter = pd.DataFrame(data=[
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Chord_Length(截面弦长)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Upper_Max_Width(叶背最大厚度)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Upper_Max_Width_Loc(叶背最大厚度位置)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Upper_Angle(叶背与尾缘夹角)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Upper_tip_coeff(叶背-前缘外形因数)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Upper_aft_part_shape(扩散点位置)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Lower_max_width(叶盆最大厚度)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Lower_max_width_loc(叶盆最大厚度位置)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Lower_Angle(叶盆与尾缘夹角)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Lower_tip_coeff(叶背-前缘外形因数)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Lower_aft_part_shape(扩散点位置)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "十一参数", "输入参数", "Tangent_Leading_Edge(前缘切向夹角)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "采样点", "输入参数", "SectionPoints(点位x,y,z)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "输出参数", "CurvePoints(点位x,y,z)"),
    ('方法参数', '叶片设计参数', '型线生成参数', "输出参数", "cpts(控制点坐标x,y,z)"),
    ('方法参数', '叶片设计参数', '曲面生成参数', "输入参数", "CurvePoints(弧线点x,y,z)"),
    ('方法参数', '叶片设计参数', '曲面生成参数', "输出参数", "未封闭曲面(.obj)"),
    ('方法参数', '叶片设计参数', '端面封闭参数', "输入参数", "未封闭曲面(.obj)"),
    ('方法参数', '叶片设计参数', '端面封闭参数', "输出参数", "封闭曲面(.obj)"),
    ('方法参数', '轨迹规划参数', '精加工算法参数', "输入参数", "cpts(控制点x,y,z)"),

])
method_parameter = Element()
method_parameter.add_object_from_dataframe(CIMSH_Parameter)
method_parameter.to_df()
# Out:
#        0       1        2     3                      4  \
# 0   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 1   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 2   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 3   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 4   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 5   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 6   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 7   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 8   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 9   方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 10  方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 11  方法参数  叶片设计参数   型线生成参数  十一参数                   输入参数
# 12  方法参数  叶片设计参数   型线生成参数   采样点                   输入参数
# 13  方法参数  叶片设计参数   型线生成参数  输出参数   CurvePoints(点位x,y,z)
# 14  方法参数  叶片设计参数   型线生成参数  输出参数       cpts(控制点坐标x,y,z)
# 15  方法参数  叶片设计参数   曲面生成参数  输入参数  CurvePoints(弧线点x,y,z)
# ...

# %% [markdown]
# ## 方法参数 - 绑定

# %%
# 单个参数
CIMSH_Method.bind_method_parameter_to_object(
    ['输入参数', 'Chord_Length(截面弦长)'],
    object_path=['叶片设计方法', '型线生成方法(Python型线程序)', '十一参数法']
)

# 批量参数
all_parameters = [
    ['输入参数1', 'Chord_Length(截面弦长)'],
    ['输入参数', 'Upper_Max_Width(叶背最大厚度)'],
    ['输入参数', 'Upper_Max_Width_Loc(叶背最大厚度位置)'],
    ['输入参数', 'Upper_Angle(叶背与尾缘夹角)'],
    ['输入参数', 'Upper_tip_coeff(叶背-前缘外形因数)'],
    ['输入参数', 'Upper_aft_part_shape(扩散点位置)'],
    ['输入参数', 'Lower_max_width(叶盆最大厚度)'],
    ['输入参数', 'Lower_max_width_loc(叶盆最大厚度位置)'],
    ['输入参数', 'Lower_Angle(叶盆与尾缘夹角)'],
    ['输入参数', 'Lower_tip_coeff(叶背-前缘外形因数)'],
    ['输入参数', 'Lower_aft_part_shape(扩散点位置)'],
    ['输入参数', 'Tangent_Leading_Edge(前缘切向夹角)']
]

# 使用组合后的列表一次性绑定所有参数
CIMSH_Method.bind_method_parameter_to_object(
    param_info=all_parameters,
    object_path=['叶片设计方法', '型线生成方法(Python型线程序)', '十一参数法']
)
CIMSH_Method_df = CIMSH_Method.to_df()
CIMSH_Method_df
# Out:
# 2024-08-09 16:46:06.611 | INFO     | imkernel.model.new_model:bind_method_parameter_to_object:502 - 成功将输入参数 'Chord_Length(截面弦长)' 绑定到对象 '十一参数法'
# 2024-08-09 16:46:06.612 | INFO     | imkernel.model.new_model:bind_method_parameter_to_object:502 - 成功将输入参数1 'Chord_Length(截面弦长)' 绑定到对象 '十一参数法'
# 2024-08-09 16:46:06.613 | INFO     | imkernel.model.new_model:bind_method_parameter_to_object:502 - 成功将输入参数 'Upper_Max_Width(叶背最大厚度)' 绑定到对象 '十一参数法'
# 2024-08-09 16:46:06.613 | INFO     | imkernel.model.new_model:bind_method_parameter_to_object:502 - 成功将输入参数 'Upper_Max_Width_Loc(叶背最大厚度位置)' 绑定到对象 '十一参数法'
# 2024-08-09 16:46:06.614 | INFO     | imkernel.model.new_model:bind_method_parameter_to_object:502 - 成功将输入参数 'Upper_Angle(叶背与尾缘夹角)' 绑定到对象 '十一参数法'
# 2024-08-09 16:46:06.615 | INFO     | imkernel.model.new_model:bind_method_parameter_to_object:502 - 成功将输入参数 'Upper_tip_coeff(叶背-前缘外形因数)' 绑定到对象 '十一参数法'
# ...

# %% [markdown]
# ## 流程模型

# %% [markdown]
# ## 流程对象创建

# %%
Process_df = pd.DataFrame(data=[
    ('叶片设计', '型线生成'),
    ('叶片设计', '曲面生成'),
    ('叶片设计', '端面封闭'),
    ('轨迹规划', '精加工轨迹规划'),
    ('加工规划', 'NC代码生成'),
    ('实际加工', '加工数据采集'),
    ('叶片检测', '采样'),
    ('叶片检测', '配准'),
    ('人工智能优化', '复杂型面加工特征参数优化选取'),
    ('人工智能优化', '面向复杂型面的铣削参数优化')
])
# 方法模型
CIMSH_Process = Element()
CIMSH_Process.add_object_from_dataframe(Process_df)
CIMSH_Process.to_df()
# Out:
#         0               1
# 0    叶片设计            型线生成
# 1    叶片设计            曲面生成
# 2    叶片设计            端面封闭
# 3    轨迹规划         精加工轨迹规划
# 4    加工规划          NC代码生成
# 5    实际加工          加工数据采集
# 6    叶片检测              采样
# 7    叶片检测              配准
# 8  人工智能优化  复杂型面加工特征参数优化选取
# 9  人工智能优化   面向复杂型面的铣削参数优化

# %% [markdown]
# ## 流程参数创建

# %%
Parameter_df = pd.DataFrame(data=[
    ('叶片设计参数', '型线生成参数', '时间参数(T)'),
    ('叶片设计参数', '型线生成参数', '空间参数(S)'),
    ('叶片设计参数', '型线生成参数', '单元对象(E)'),
    ('叶片设计参数', '型线生成参数', '方法对象(F)'),
    ('叶片设计参数', '曲面生成参数', '时间参数(T)'),
    ('叶片设计参数', '曲面生成参数', '空间参数(S)'),
    ('叶片设计参数', '曲面生成参数', '单元对象(E)'),
    ('叶片设计参数', '曲面生成参数', '方法对象(F)'),
    ('叶片设计参数', '端面封闭参数', '时间参数(T)'),
    ('叶片设计参数', '端面封闭参数', '空间参数(S)'),
    ('叶片设计参数', '端面封闭参数', '单元对象(E)'),
    ('叶片设计参数', '端面封闭参数', '方法对象(F)'),
    ('轨迹规划参数', '精加工轨迹规划参数', '时间参数(T)'),
    ('轨迹规划参数', '精加工轨迹规划参数', '空间参数(S)'),
    ('轨迹规划参数', '精加工轨迹规划参数', '单元对象(E)'),
    ('轨迹规划参数', '精加工轨迹规划参数', '方法对象(F)'),
    ('加工规划参数', 'NC代码生成参数', '时间参数(T)'),
    ('加工规划参数', 'NC代码生成参数', '空间参数(S)'),
    ('加工规划参数', 'NC代码生成参数', '单元对象(E)'),
    ('加工规划参数', 'NC代码生成参数', '方法对象(F)'),
    ('实际加工参数', '加工数据采集参数', '时间参数(T)'),
    ('实际加工参数', '加工数据采集参数', '空间参数(S)'),
    ('实际加工参数', '加工数据采集参数', '单元对象(E)'),
    ('实际加工参数', '加工数据采集参数', '方法对象(F)'),
    ('叶片检测参数', '采样参数', '时间参数(T)'),
    ('叶片检测参数', '采样参数', '空间参数(S)'),
    ('叶片检测参数', '采样参数', '单元对象(E)'),
    ('叶片检测参数', '采样参数', '方法对象(F)'),
    ('叶片检测参数', '配准参数', '时间参数(T)'),
    ('叶片检测参数', '配准参数', '空间参数(S)'),
    ('叶片检测参数', '配准参数', '单元对象(E)'),
    ('叶片检测参数', '配准参数', '方法对象(F)'),
    ('人工智能优化参数', '复杂型面加工特征参数优化选取参数', '时间参数(T)'),
    ('人工智能优化参数', '复杂型面加工特征参数优化选取参数', '空间参数(S)'),
    ('人工智能优化参数', '复杂型面加工特征参数优化选取参数', '单元对象(E)'),
    ('人工智能优化参数', '复杂型面加工特征参数优化选取参数', '方法对象(F)'),
    ('人工智能优化参数', '面向复杂型面的铣削参数优化参数', '时间参数(T)'),
    ('人工智能优化参数', '面向复杂型面的铣削参数优化参数', '空间参数(S)'),
    ('人工智能优化参数', '面向复杂型面的铣削参数优化参数', '单元对象(E)'),
    ('人工智能优化参数', '面向复杂型面的铣削参数优化参数', '方法对象(F)')
])

# 流程参数
CIMSH_Process_Parameter = Element()
CIMSH_Process_Parameter.add_object_from_dataframe(Parameter_df)
CIMSH_Process_Parameter.to_df()
# Out:
#            0                 1        2
# 0     叶片设计参数            型线生成参数  时间参数(T)
# 1     叶片设计参数            型线生成参数  空间参数(S)
# 2     叶片设计参数            型线生成参数  单元对象(E)
# 3     叶片设计参数            型线生成参数  方法对象(F)
# 4     叶片设计参数            曲面生成参数  时间参数(T)
# 5     叶片设计参数            曲面生成参数  空间参数(S)
# 6     叶片设计参数            曲面生成参数  单元对象(E)
# 7     叶片设计参数            曲面生成参数  方法对象(F)
# 8     叶片设计参数            端面封闭参数  时间参数(T)
# 9     叶片设计参数            端面封闭参数  空间参数(S)
# 10    叶片设计参数            端面封闭参数  单元对象(E)
# 11    叶片设计参数            端面封闭参数  方法对象(F)
# 12    轨迹规划参数         精加工轨迹规划参数  时间参数(T)
# 13    轨迹规划参数         精加工轨迹规划参数  空间参数(S)
# 14    轨迹规划参数         精加工轨迹规划参数  单元对象(E)
# 15    轨迹规划参数         精加工轨迹规划参数  方法对象(F)
# 16    加工规划参数          NC代码生成参数  时间参数(T)
# 17    加工规划参数          NC代码生成参数  空间参数(S)
# 18    加工规划参数          NC代码生成参数  单元对象(E)
# 19    加工规划参数          NC代码生成参数  方法对象(F)
# 20    实际加工参数          加工数据采集参数  时间参数(T)
# 21    实际加工参数          加工数据采集参数  空间参数(S)
# ...

# %% [markdown]
# ## 单元参数关联

# %%
# 批量参数
Process_parameters = [
    "时间参数(T)",
    "空间参数(S)",
    "单元对象(E)",
    "方法对象(F)"
]
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['叶片设计', '型线生成']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['叶片设计', '曲面生成']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['叶片设计', '端面封闭']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['轨迹规划', '精加工轨迹规划']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['加工规划', 'NC代码生成']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['实际加工', '加工数据采集']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['叶片检测', '采样']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['叶片检测', '配准']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['人工智能优化', '复杂型面加工特征参数优化选取']
)
# 使用组合后的列表一次性绑定所有参数
CIMSH_Process.bind_parameter_to_object(
    parameter_info=Process_parameters,
    object_path=['人工智能优化', '面向复杂型面的铣削参数优化']
)
CIMSH_Process_df = CIMSH_Process.to_df()
CIMSH_Process_df
# Out:
# 2024-08-09 16:32:34.499 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '时间参数(T)' 关联到对象 '型线生成'
# 2024-08-09 16:32:34.499 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '空间参数(S)' 关联到对象 '型线生成'
# 2024-08-09 16:32:34.500 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '单元对象(E)' 关联到对象 '型线生成'
# 2024-08-09 16:32:34.500 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '方法对象(F)' 关联到对象 '型线生成'
# 2024-08-09 16:32:34.502 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '时间参数(T)' 关联到对象 '曲面生成'
# 2024-08-09 16:32:34.503 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '空间参数(S)' 关联到对象 '曲面生成'
# 2024-08-09 16:32:34.503 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '单元对象(E)' 关联到对象 '曲面生成'
# 2024-08-09 16:32:34.503 | INFO     | imkernel.model.new_model:bind_parameter_to_object:538 - 成功将参数 '方法对象(F)' 关联到对象 '曲面生成'
# ...

# %% [markdown]
# # 统一模型

# %% [markdown]
# ## 数据模型

# %%
CIMSH_Element.set_value(
    "Blade.BladeCross.BladePolyLine.ElevenParameters", [0, 0.4149, 0.2098, 0.0582, 0.4492, 0.3339, 0.234, 0.7289, 0.2497, 0.52, 0.8523, 0.5]
)
CIMSH_Element.set_value(
    "Blade.BladeCross.BladePolyLine.ElevenParameters", [20, 0.4149, 0.2098, 0.0582, 0.4492, 0.3339, 0.234, 0.7289, 0.2497, 0.52, 0.8523, 0.5]
)
CIMSH_Element.set_value(
    "BladeCross.BladePolyLine.ElevenParameters", [50, 0.4149, 0.2098, 0.0582, 0.4492, 0.3339, 0.234, 0.7289, 0.2497, 0.52, 0.8523, 0.5]
)
CIMSH_Element.set_value(
    "Blade.BladeCross.BladePolyLine.ElevenParameters", [80, 0.4149, 0.2098, 0.0582, 0.4492, 0.3339, 0.234, 0.7289, 0.2497, 0.52, 0.8523, 0.5]
)
CIMSH_Element.set_value(
    "BladeCross.BladePolyLine.ElevenParameters", [100, 0.4149, 0.2098, 0.0582, 0.4492, 0.3339, 0.234, 0.7289, 0.2497, 0.52, 0.8523, 0.5]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 CIMSH_Element.set_value(
#       2     "Blade.BladeCross.BladePolyLine", [0,0.4149,0.2098,0.0582,0.4492,0.3339,0.234,0.7289,0.2497,0.52,0.8523,0.5]
#       3 )
#       4 CIMSH_Element.set_value(
#       5     "Blade.BladeCross.BladePolyLine.ElevenParameters", [20,0.4149,0.2098,0.0582,0.4492,0.3339,0.234,0.7289,0.2497,0.52,0.8523,0.5]
#       6 )
#       7 CIMSH_Element.set_value(
#       8     "BladeCross.BladePolyLine.ElevenParameters", [50,0.4149,0.2098,0.0582,0.4492,0.3339,0.234,0.7289,0.2497,0.52,0.8523,0.5]
#       9 )
#
# AttributeError: 'Element' object has no attribute 'set_value'
